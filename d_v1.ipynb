# %% [markdown]
# <a href="https://colab.research.google.com/github/GHakshay/ML_Practice/blob/master/d_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('student_info.csv')

# %%
# pie chart for student's age
p=plt.pie(df.iloc[0:,4], labels=df.iloc[0:,2], shadow =True, autopct='%1.1f%%')

# %%
# pie chart for student's marks
pi1=plt.pie(df.iloc[0:,3], labels=df.iloc[0:,2], shadow =True, autopct='%1.1f%%')
